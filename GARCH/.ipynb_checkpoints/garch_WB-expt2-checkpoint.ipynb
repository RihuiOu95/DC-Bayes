# %%
# Calling libraries:
from __future__ import division
# %matplotlib inline
import numpy as np, time, matplotlib.pyplot as plt, math, pandas, numpy.random as npr, pystan as ps, pickle
from pylab import plot, show, legend
from time import time
from scipy.stats import *
from functions_garch import *

# %%
sm = ps.StanModel(file="garch_WB.stan")
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_f0ef85016fbe1114f4bfb9978c846a08 NOW.
# In file included from /var/folders/vm/bnpn0t152gn54b0_nhp78xf40000gp/T/pystan_aq7d18co/stanfit4anon_model_f0ef85016fbe1114f4bfb9978c846a08_7864015519991363804.cpp:771:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/numpy/core/include/numpy/arrayobject.h:4:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/numpy/core/include/numpy/ndarrayobject.h:12:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/numpy/core/include/numpy/ndarraytypes.h:1944:
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: "Using deprecated NumPy API, disable it with "          "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-W#warnings]
# #warning "Using deprecated NumPy API, disable it with " \
#  ^
# /var/folders/vm/bnpn0t152gn54b0_nhp78xf40000gp/T/pystan_aq7d18co/stanfit4anon_model_f0ef85016fbe1114f4bfb9978c846a08_7864015519991363804.cpp:9546:30: warning: comparison of integers of different signs: 'Py_ssize_t' (aka 'long') and 'std::__1::vector<std::__1::basic_string<char>, std::__1::allocator<std::__1::basic_string<char> > >::size_type' (aka 'unsigned long') [-Wsign-compare]
#     __pyx_t_12 = ((__pyx_t_9 != __pyx_v_fitptr->param_names_oi().size()) != 0);
#                    ~~~~~~~~~ ^  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /var/folders/vm/bnpn0t152gn54b0_nhp78xf40000gp/T/pystan_aq7d18co/stanfit4anon_model_f0ef85016fbe1114f4bfb9978c846a08_7864015519991363804.cpp:780:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/pystan/py_var_context.hpp:12:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/pystan/stan/src/stan/io/dump.hpp:6:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat.hpp:336:
# In file included from /opt/anaconda3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_log.hpp:5:
# /opt/anaconda3/lib/python3.9/site-packages/pystan/stan/lib/stan_math/stan/math/prim/mat/prob/poisson_log_glm_lpmf.hpp:64:59: warning: unused typedef 'T_alpha_val' [-Wunused-local-typedef]
#       typename partials_return_type<T_alpha>::type>::type T_alpha_val;
#                                                           ^
# In file included from /var/folders/vm/bnpn0t152gn54b0_nhp78xf40000gp/T/pystan_aq7d18co/stanfit4anon_model_f0ef85016fbe1114f4bfb9978c846a08_7864015519991363804.cpp:783:
# /var/folders/vm/bnpn0t152gn54b0_nhp78xf40000gp/T/pystan_aq7d18co/anon_model_f0ef85016fbe1114f4bfb9978c846a08.hpp:179:24: warning: unused typedef 'local_scalar_t__' [-Wunused-local-typedef]
#         typedef double local_scalar_t__;
#                        ^
# 4 warnings generated.

# %%
T = 2000
p = 5
q = 3
d = 10
X = npr.randn(d,T)
omega = 1.0
rescale = 3.00
beta = np.ones(p) / (rescale * p)
alpha = np.ones(q) / (rescale * q)
b = npr.randn(d)

# %%
alpha, beta
# Out:
# (array([0.11111111, 0.11111111, 0.11111111]),
#  array([0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667]))

# %%
sigsq, y = simulate_data(T, omega, beta, alpha, b, X)

# %%
fig = plt.figure(figsize=(18,4))
plt.subplot(121)
plt.plot(sigsq, color="red")
plt.xlim(-0.005*T,1.005*T)
plt.title("Variance", fontsize=14)
plt.xlabel("Time", fontsize=13)
plt.grid(True)

plt.subplot(122)
plt.plot(y)
plt.xlim(-0.005*T,1.005*T)
plt.title("Observations", fontsize=14)
plt.xlabel("Time", fontsize=13)
plt.grid(True)

plt.subplots_adjust(wspace=1e-1)
fig.savefig('garch_data.pdf', bbox_inches='tight', dpi=2000)

# %%
# save data
dat = dict(y=y, X=X, sigsq=sigsq, alpha=alpha, beta=beta, b=b, omega=omega)
file = open("data.pkl", "wb")
pickle.dump(dat, file)
file.close()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
x = adfuller(sigsq)

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 4))

# Plot ACF on the first subplot
plot_acf(y, lags=50, ax = axes[0])
plot_pacf(y, lags=50, ax = axes[1])
plt.show()
fig.savefig('garch_data_acf.pdf', bbox_inches='tight', dpi=2000)

# %%
data = dict(T=T, p=p, q=q, r=max(p,q), d=d, y=y, X=X, power=1.)

# %% [markdown]
# ### MCMC on full dataset:

# %%
n_chains = 1
n_iter = 1000
data = dict(T=T, p=p, q=q, r=max(p,q), d=d, y=y, X=X, power=1.)
start = time()
fit = sm.sampling(data=data, thin=1, n_jobs=1, chains=n_chains, init="random", iter=n_iter)
mle = sm.optimizing(data=data)
print(round((time()-start)/60,2), "minutes to run")

file = open("full_mcmc.pkl", "wb")
trace = fit.extract()
pickle.dump(fit.extract(), file)
file.close()

file = open("full_mle.pkl", "wb")
pickle.dump(mle, file)
file.close()
# Out:
# WARNING:pystan:25 of 500 iterations ended with a divergence (5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
#
# Gradient evaluation took 0.005428 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 54.28 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 232.466 seconds (Warm-up)
#                240.38 seconds (Sampling)
#                472.847 seconds (Total)
#
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# 7.85 minutes to run
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Initial log joint probability = -328381
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -4061.31    0.00266368       0.79343      0.5171      0.5171       24
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       29       -4061.3   0.000366261     0.0239575           1           1       35
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
mle.items()
# Out:
# odict_items([('omega', array(1.79126453)), ('beta', array([1.75704633e-22, 2.14716931e-33, 6.84403782e-15, 2.23252346e-58,
#        1.76078098e-38])), ('alpha', array([0.15172396, 0.10472029, 0.22042952])), ('b', array([ 0.49157399,  0.07421065, -0.90770038, -0.2642428 , -1.83582559,
#        -0.36801101, -0.02179069, -0.65750518, -1.616178  , -0.29862473]))])

# %% [markdown]
# ### Divide-and-conquer:

# %%
for i in range(m) :
    tstart, tend = tstarts[i], tends[i]
    data = dict(T=tend-tstart, p=p, q=q, r=max(p,q), d=d, y=y[tstart:tend], X=X[:,tstart:tend], power=T/(tend-tstart))
    
    fit = sm.sampling(data=data, thin=1, n_jobs=min(10,n_chains), chains=n_chains, init="random", iter=n_iter)
    file = open("mcmc_wb_chunk"+str(i+1)+".pkl", "wb")
    pickle.dump(fit.extract(), file)
    file.close()
    
    mle = sm.optimizing(data=data)
    file = open("mle_chunk"+str(i+1)+".pkl", "wb")
    pickle.dump(mle, file)
    file.close()
# Out:
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is nan, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# Gradient evaluation took 0.000586 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 5.86 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 12.2233 seconds (Warm-up)
#                9.81636 seconds (Sampling)
#                22.0397 seconds (Total)
#
# Initial log joint probability = -168382
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -4323.02      0.210026       15.3804      0.9927      0.9927       23
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -4311.27     0.0479262       8.48519           1           1       47
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -4305.72     0.0569548        2.0941           1           1       70
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -4305.67      0.113545      0.654113           1           1       92
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -4305.65    0.00423536      0.146079           1           1      116
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -4305.64     0.0429389      0.636978           1           1      136
#     Iter      log
# WARNING:pystan:1 of 500 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -4305.61     0.0414889      0.230889           1           1      158
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159      -4305.61    0.00106714      0.216294      0.1803      0.1803      180
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      179      -4305.61      0.159458       1.02999           1           1      204
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199      -4305.59      0.223122      0.157027           1           1      226
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      219      -4305.47       1.10786       1.71414           1           1      258
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      239      -4305.44     0.0174402      0.237847      0.7148      0.7148      278
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      255      -4305.44    0.00614446     0.0615721      0.1996      0.9468      295
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Gradient evaluation took 0.000417 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.17 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 17.6974 seconds (Warm-up)
#                13.5038 seconds (Sampling)
#                31.2012 seconds (Total)
#
# Initial log joint probability = -103833
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -3730.71      0.906279       11.9286           1           1       24
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39       -3720.3     0.0735654       5.03974           1           1       48
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -3710.96      0.135927       27.1109      0.6536      0.6536       74
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -3708.74     0.0344034       1.33194           1           1       96
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -3708.62      0.192919        1.6054           1           1      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -3708.51      0.102551      0.785292           1           1      140
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -3708.49      0.487712      0.839387           1           1      160
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159      -3708.48     0.0107802      0.368724      0.5484      0.5484      184
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      167      -3708.48     0.0192692      0.053684           1           1      193
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# WARNING:pystan:1 of 500 iterations ended with a divergence (0.2 %).
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Gradient evaluation took 0.000427 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.27 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 17.0222 seconds (Warm-up)
#                13.728 seconds (Sampling)
#                30.7501 seconds (Total)
#
# Initial log joint probability = -72364.7
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -3695.98     0.0824739       6.98828           1           1       22
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -3695.44     0.0024035      0.658805           1           1       43
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -3695.42    0.00203938      0.362394           1           1       64
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       63      -3695.42    0.00046857     0.0601407           1           1       68
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# WARNING:pystan:6 of 500 iterations ended with a divergence (1.2 %).
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Gradient evaluation took 0.000418 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.18 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 33.4097 seconds (Warm-up)
#                41.963 seconds (Sampling)
#                75.3726 seconds (Total)
#
# Initial log joint probability = -88503
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -3844.91      0.175226       7.38669      0.9793      0.9793       22
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39         -3836      0.197014       25.6607      0.4239           1       47
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59       -3831.4     0.0854524       5.39502           1           1       71
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -3830.49     0.0459849       2.67173      0.3981           1       92
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -3830.22     0.0320278        2.3929      0.8575      0.8575      113
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -3829.71       1.86038        8.1767           1           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -3829.66      0.203336      0.400788           1           1      154
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159      -3829.65     0.0213564      0.424476           1           1      176
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      172      -3829.65     0.0162767     0.0549519           1           1      189
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# WARNING:pystan:1 of 500 iterations ended with a divergence (0.2 %).
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# Gradient evaluation took 0.000479 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.79 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 30.7296 seconds (Warm-up)
#                60.2528 seconds (Sampling)
#                90.9824 seconds (Total)
#
# Initial log joint probability = -127139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -3908.91      0.265921       23.3803           1           1       25
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -3904.42     0.0328266       4.77549           1           1       45
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -3902.61     0.0638523       6.76846      0.8571      0.8571       68
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -3901.86     0.0400339        1.7306           1           1       89
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -3901.78     0.0223259       1.40477           1           1      109
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -3901.66     0.0181455       1.65531      0.5959      0.5959      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -3901.54      0.161711       2.47587      0.4734           1      151
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159      -3901.52     0.0206148      0.377382           1           1      173
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      179      -3901.51      0.257604      0.538826           1           1      193
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       -3901.5     0.0114689      0.749051      0.4919           1      214
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      218       -3901.5    0.00304629     0.0424029           1           1      234
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Gradient evaluation took 0.000419 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.19 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 40.892 seconds (Warm-up)
#                29.7932 seconds (Sampling)
#                70.6851 seconds (Total)
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Initial log joint probability = -110006
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -3930.68      0.221402       28.0742      0.9718      0.9718       25
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -3916.74     0.0221961       2.34451           1           1       50
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -3916.55      0.161474       6.65067      0.2995           1       75
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -3916.46     0.0043607      0.590127           1           1       95
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -3916.22     0.0313317       8.41711       0.474      0.0474      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -3916.19    0.00300631      0.578276           1           1      141
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -3916.13      0.155807       3.31695           1           1      162
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159      -3916.11      0.132177       4.05874       0.345       0.345      185
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      178      -3916.08     0.0109767      0.070887           1           1      206
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# WARNING:pystan:7 of 500 iterations ended with a divergence (1.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Gradient evaluation took 0.000442 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.42 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 15.5457 seconds (Warm-up)
#                7.62284 seconds (Sampling)
#                23.1685 seconds (Total)
#
# Initial log joint probability = -39059.5
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -3860.49      0.685487       37.4192           1           1       23
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39       -3848.9      0.225795       40.1041      0.0739      0.7533       47
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -3847.58    0.00662978      0.465375           1           1       70
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -3847.36       1.06034        4.7693           1           1       90
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -3839.26      0.149971       18.9724      0.8942      0.8942      125
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -3837.32      0.246409       5.26604           1           1      146
#     Iter      log
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# WARNING:pystan:2 of 500 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:11 of 500 iterations ended with a divergence (2.2 %).
# prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -3836.96      0.364409        1.3408       1.266      0.1266      169
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      159      -3836.94      0.557303      0.848282           1           1      192
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      170      -3836.94     0.0196592     0.0758161      0.9422      0.9422      206
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Gradient evaluation took 0.000568 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 5.68 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 19.9368 seconds (Warm-up)
#                13.8662 seconds (Sampling)
#                33.803 seconds (Total)
#
# Initial log joint probability = -33521.3
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -4425.87      0.137534       16.6748           1           1       24
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -4375.53    0.00775802       4.83002      0.6881      0.6881       47
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -4374.75     0.0154984       2.26933           1           1       70
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -4374.46     0.0653265      0.960882      0.8872      0.8872       92
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -4374.17      0.117409       2.53368           1           1      113
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -4374.11     0.0550283      0.458478           1           1      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -4374.11    0.00502244      0.215273           1           1      158
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      152      -4374.11    0.00231277     0.0533462      0.8908      0.8908      173
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Gradient evaluation took 0.000414 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.14 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sa
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# mpling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 14.5644 seconds (Warm-up)
#                7.08716 seconds (Sampling)
#                21.6515 seconds (Total)
#
# Initial log joint probability = -65219.8
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -4258.32      0.394876        49.087           1           1       22
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -4231.93     0.0819072       10.5805           1           1       44
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -4227.93      0.186307       2.18199           1           1       65
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -4227.52        1.4156       0.77314           1           1       87
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -4227.52      0.518409      0.679805           1           1      109
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -4227.48      0.501894      0.312041           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -4227.47      0.640238      0.140159      0.6192      0.6192      153
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      151      -4227.47        9.2142      0.105741      0.9103      0.9103      167
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
# Exception: normal_lpdf: Scale parameter is 0, but must be > 0!  (in 'garch_WB.stan' at line 39)
#
# If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
# but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#
# WARNING:pystan:2 of 500 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# Gradient evaluation took 0.000452 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 4.52 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:   1 / 1000 [  0%]  (Warmup)
# Iteration: 100 / 1000 [ 10%]  (Warmup)
# Iteration: 200 / 1000 [ 20%]  (Warmup)
# Iteration: 300 / 1000 [ 30%]  (Warmup)
# Iteration: 400 / 1000 [ 40%]  (Warmup)
# Iteration: 500 / 1000 [ 50%]  (Warmup)
# Iteration: 501 / 1000 [ 50%]  (Sampling)
# Iteration: 600 / 1000 [ 60%]  (Sampling)
# Iteration: 700 / 1000 [ 70%]  (Sampling)
# Iteration: 800 / 1000 [ 80%]  (Sampling)
# Iteration: 900 / 1000 [ 90%]  (Sampling)
# Iteration: 1000 / 1000 [100%]  (Sampling)
#
#  Elapsed Time: 18.6808 seconds (Warm-up)
#                13.6789 seconds (Sampling)
#                32.3597 seconds (Total)
#
# Initial log joint probability = -32771.2
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       19      -4087.65     0.0822972       5.46486           1           1       23
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39      -4086.66     0.0520242       4.99233      0.4536      0.4536       45
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59      -4086.36     0.0680025       3.52488           1           1       68
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79      -4084.15      0.378218        6.8547           1           1       89
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99      -4083.61      0.152733       4.77626      0.3905           1      110
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      119      -4083.51     0.0274881      0.680959      0.3086           1      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139      -4083.49     0.0110389      0.646538      0.5544      0.5544      155
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      152      -4083.49    0.00233829     0.0855325           1           1      169
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %% [markdown]
# # Laplace Approx

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torch.nn.functional as F

# %%
class GARCH(nn.Module):
    def __init__(self, p, q):
        super(GARCH, self).__init__()
        self.p = p
        self.q = q
        self.raw_omega = nn.Parameter(-torch.randn(1))
        self.raw_alpha = nn.Parameter(-10 * torch.randn(p))
        self.raw_beta = nn.Parameter(-10 * torch.randn(q))

    def forward(self, returns):
        T = returns.shape[0]
        sigma2 = torch.zeros(T)
        omega = F.softplus(self.raw_omega)
        alpha = F.softplus(self.raw_alpha)
        beta = F.softplus(self.raw_beta)
        
        for t in range(max(self.p, self.q)):
            sigma2[t] = returns[:self.p].pow(2).mean()

        for t in range(max(self.p, self.q), T):
            alpha_term = torch.sum(alpha * returns[max(0, t-self.p):t].pow(2).clone())
            beta_term = torch.sum(beta * sigma2[max(0, t-self.q):t].clone())
            sigma2[t] = omega + alpha_term + beta_term

        return sigma2

# Negative log-likelihood loss
def nll_loss(sigma2, returns):
    T = len(returns)
    log_likelihood = -(torch.log(sigma2) + returns.pow(2) / sigma2)
    return -torch.sum(log_likelihood) 

# Hyperparameters
p, q = 2, 2
learning_rate = 0.02
num_epochs = 300

# Sample data
returns = torch.tensor(y).reshape(len(y),1)

# Model and optimizer
model = GARCH(p, q)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
F.softplus(model.raw_alpha)
# Out:
# tensor([1.2554e+00, 6.2451e-06], grad_fn=<SoftplusBackward0>)

# %%
# Train the model
for epoch in range(num_epochs):
    optimizer.zero_grad()
    sigma2 = model(returns)
    loss = nll_loss(sigma2, returns)
    loss.backward()
    optimizer.step()

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.6f}')

# Get the estimated conditional variances
estimated_sigma2 = model(returns)
print("Estimated conditional variances:", estimated_sigma2)
# Out:
# Epoch [10/300], Loss: nan
# Epoch [20/300], Loss: nan
# Epoch [30/300], Loss: nan
# Epoch [40/300], Loss: nan
# Epoch [50/300], Loss: nan
# Epoch [60/300], Loss: nan
# Epoch [70/300], Loss: nan
# Epoch [80/300], Loss: nan
# Epoch [90/300], Loss: nan
# Epoch [100/300], Loss: nan
# Epoch [110/300], Loss: nan
# Epoch [120/300], Loss: nan
# Epoch [130/300], Loss: nan
# Epoch [140/300], Loss: nan
# Epoch [150/300], Loss: nan
# Epoch [160/300], Loss: nan
# Epoch [170/300], Loss: nan
# Epoch [180/300], Loss: nan
# Epoch [190/300], Loss: nan
# Epoch [200/300], Loss: nan
# Epoch [210/300], Loss: nan
# Epoch [220/300], Loss: nan
# Epoch [230/300], Loss: nan
# Epoch [240/300], Loss: nan
# Epoch [250/300], Loss: nan
# Epoch [260/300], Loss: nan
# Epoch [270/300], Loss: nan
# Epoch [280/300], Loss: nan
# Epoch [290/300], Loss: nan
# Epoch [300/300], Loss: nan
# Estimated conditional variances: tensor([0.4310, 0.4310,    nan,  ...,    nan,    nan,    nan],
#        grad_fn=<CopySlices>)
